# %%
print("Hello python")
print(5+8)
print(5*8)
print(99*99)
print(10/5)
print(12//3)
5+int('5')
#float
float('99')
float('-1.5')
2 * (1 + 2) ** 2 - 2 ** 2 * 2#運算式(expression)
value=2 * (1 + 2) ** 2 - 2 ** 2 * 2#敍述式(statement)
# Out:
# Hello python
# 13
# 40
# 9801
# 2.0
# 4
# -1.5
