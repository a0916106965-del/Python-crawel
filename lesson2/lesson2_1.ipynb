# %%
print("Hello python")
# Out:
# 執行具有 'Python-crawel (Python 3.11.14)' 的儲存格需要 ipykernel 套件。
#
# 將 'ipykernel' 安裝到 Python 環境中。
#
# 命令: '"c:/Users/User/Documents/Git hub/Python-crawel/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
