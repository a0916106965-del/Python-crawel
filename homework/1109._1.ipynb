# %% [markdown]
# print("hello")

# %%
print("hello")
# Out:
# hello

# %%
print(5+5)
print(10-2)
print(5**2)
# Out:
# 10
# 8
# 25

# %%
2+2
5+5
# Out:
# 10

# %%
A=1
B=2
velue=A+B
print(velue)
# Out:
# 3

# %%
score=50+20+30+60
average=score/4
print("學生總分為",score)
print("學生平均為",average)
# Out:
# 學生總分為 160
# 學生平均為 40.0

# %%
chinese = 78
chinese = chinese + 5
english = 92
math = 67
total = chinese + english + math
avg=total/3
avg//10
# Out:
# 8.0
